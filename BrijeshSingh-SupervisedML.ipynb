# %% [markdown]
# ### Assignment Supervised ML --------------------------------------Brijesh Singh

# %% [markdown]
# ##### a)	Describe the working of a Decision Tree algorithm. How does it decide on the best features to split the data? What are some advantages and disadvantages of using Decision Trees?

# %% [markdown]
# ###### A Decision Tree is a supervised machine learning algorithm used for classification and regression. It works by recursively splitting the dataset into smaller subsets based on feature values, forming a tree‑like structure.
#
# ##### Working Steps
# ###### Start at the root node with the full dataset.
#
# ###### For every feature, the algorithm evaluates all possible split points.
#
# ###### It selects the best feature + best threshold that produces the purest child nodes.
#
# ###### The dataset is split into two or more branches.
#
# ###### The process repeats recursively on each child node (this is called recursive partitioning).
#
# ###### Splitting stops when:
#
# ###### - All samples in a node belong to one class
#
# ###### - Maximum depth is reached
#
# ###### - Minimum samples per node is reached
#
# ###### - No further improvement is possible
#
# ###### The final nodes are called leaf nodes, and each leaf represents a class label (classification) or a value (regression).
#
# #### 2. How a Decision Tree Chooses the Best Feature to Split
# ###### A Decision Tree chooses the best feature using impurity reduction.
# ###### The goal is to create child nodes that are as pure as possible.
#
# ###### Common impurity measures
# ###### (a) Gini Impurity (CART – Classification and Regression Trees)
#
# ###### 𝐺𝑖𝑛𝑖
# ###### Lower Gini = purer node.
#
# ###### (b) Entropy (Information Gain – ID3, C4.5)
# ######    Higher Information Gain = better split.
#
# ###### (c) For Regression Trees
# ######    MSE (Mean Squared Error) reduction
#
# ######    MAE (Mean Absolute Error) reduction
#
# ###### 3. Advantages of Decision Trees
#     - Easy to understand and interpret
#     - Looks like human decision-making
#     - Can be visualized graphically
#     - No need for feature scaling
#     - Works with raw data
#     - No normalization/standardization required
#
#     ✔ Handles both numerical and categorical data
#     ✔ Captures non-linear relationships
#     ✔ Requires little data preprocessing
#     No need for dummy variables in some implementations
#
#     Handles missing values (CART)
#
# 4. Disadvantages of Decision Trees
#     ✘ Highly prone to overfitting
#     Trees grow deep and memorize training data
#
#     Needs pruning or max-depth control
#
#     ✘ Unstable
#         Small changes in data → completely different tree
#
#     ✘ Biased toward features with many categories
#         Categorical features with many levels may dominate splits
#
#     ✘ Not great for continuous smooth predictions
#         Regression trees produce step‑wise predictions

# %% [markdown]
# #### b)	Use the Life Expectancy Prediction dataset from below Kaggle link and create an end to end project on Jupyter/Colab.

# %% [markdown]
# 1. https://github.com/MyGit-App/Supervised-ML.git
#
#     BackendModelFile: - LifeExpentency.ipynb
#
#     Streamlit File - app_LifeExpentency.py
#
#     Streamlit App Link: https://lifeexpectancy-prediction.streamlit.app/

# %% [markdown]
# #### c)	Use the Income Classification dataset from below Kaggle link and create an end to end project on Jupyter/Colab.

# %% [markdown]
# 1. https://github.com/MyGit-App/Supervised-ML.git
#
#     BackendModelFile: - IncomeEvaluation.ipynb
#
#     Streamlit File - app_IncomeEvaluation.py
#
#     Streamlit App Link: https://lifeexpectancy-pred.streamlit.app/

# %% [markdown]
# ##### d)	What is the difference between Bagging Classifier and voting classifier. Explain the working of both the algorithms.

# %% [markdown]
# Bagging Classifier vs Voting Classifier
# 1. Bagging Classifier
# Working:
#
# Bagging (Bootstrap Aggregating) trains multiple models of the same algorithm (e.g., many Decision Trees).
#
# Each model is trained on a different bootstrapped sample of the training data.
#
# Final prediction is made by:
#
# Majority vote (classification)
#
# Averaging (regression)
#
# Purpose:
# Reduces variance and prevents overfitting.
#
# 2. Voting Classifier
# Working:
#
# Voting combines different types of models (e.g., Logistic Regression + SVM + Random Forest).
#
# All models are trained on the same dataset.
#
# Final prediction is made by:
#
# Hard voting: majority class vote
#
# Soft voting: average predicted probabilities

# %% [markdown]
# ##### e)	Explain the Bayes theorem in Naïve Bayes Algorithm.

# %% [markdown]
# Bayes Theorem in Naïve Bayes Algorithm
# Naïve Bayes is a probabilistic classification algorithm based on Bayes’ Theorem, which describes how to update the probability of a class given new evidence (features).
#
# Bayes’ Theorem
# 𝑃(𝑌∣𝑋)=𝑃(𝑋∣𝑌)*𝑃(𝑌)/𝑃(𝑋)
#
# Where:
#
# 𝑌 = class label
#
# 𝑋 = input features
#
# 𝑃(𝑌∣𝑋) = posterior probability (what we want to predict)
#
# 𝑃(𝑋∣𝑌) = likelihood
#
# 𝑃(𝑌) = prior probability of the class
#
# 𝑃(𝑋) = evidence (normalizing constant)
#
# How Naïve Bayes Uses Bayes’ Theorem
# The algorithm computes this value for each class and predicts the class with the highest posterior probability.
# Naïve Bayes applies Bayes’ Theorem with the assumption that all features independently contribute to the probability of a class.
# This makes the algorithm fast, simple, and effective even when the independence assumption is not perfectly true.
